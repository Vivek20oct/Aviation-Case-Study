# %% [markdown]
# # 1. Data Loading and Initial Exploration:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\vivek\Downloads\Important  doc\AviationData - AviationData.csv")
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\1693642178.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\vivek\Downloads\Important  doc\AviationData - AviationData.csv")

# %%
df.head(8)
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
# 5  20170710X52551           Accident      NYC79AA106  1979-09-17
# 6  20001218X45446           Accident      CHI81LA106  1981-08-01
# 7  20020909X01562           Accident      SEA82DA022  1982-01-01
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# ...

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %% [markdown]
# # 2. Data Cleaning:

# %%
df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
missing_percentage=(df.isnull().sum() * 100 /len(df)).round(2)

# %%
missing_percentage
# Out:
# Event.Id                   0.00
# Investigation.Type         0.00
# Accident.Number            0.00
# Event.Date                 0.00
# Location                   0.06
# Country                    0.25
# Latitude                  61.32
# Longitude                 61.33
# Airport.Code              43.60
# Airport.Name              40.71
# Injury.Severity            1.12
# Aircraft.damage            3.59
# Aircraft.Category         63.68
# Registration.Number        1.55
# Make                       0.07
# Model                      0.10
# Amateur.Built              0.11
# Number.of.Engines          6.84
# Engine.Type                7.98
# FAR.Description           63.97
# Schedule                  85.85
# Purpose.of.flight          6.97
# Air.carrier               81.27
# Total.Fatal.Injuries      12.83
# Total.Serious.Injuries    14.07
# Total.Minor.Injuries      13.42
# Total.Uninjured            6.65
# Weather.Condition          5.05
# Broad.phase.of.flight     30.56
# ...

# %%
df['fatality_level'] = df['Injury.Severity'].str.extract(r'(\d+)', expand=False)
df['fatality_level'] = pd.to_numeric(df['fatality_level'], errors='coerce')

# %%
def numeric_missing_values(df,colmn):
    for col in colmn:
        df[col].fillna(0,inplace=True)
    return df

# %%
columns=['Total.Uninjured' , 'Total.Minor.Injuries' ,'Total.Serious.Injuries' , 'Total.Fatal.Injuries' , 'fatality_level']

# %%
df=numeric_missing_values(df,columns)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\297039961.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0,inplace=True)

# %%
df['Number.of.Engines'].fillna(df['Number.of.Engines'].median(),inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\585569098.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Number.of.Engines'].fillna(df['Number.of.Engines'].median(),inplace=True)

# %%
df['Event.Date']=pd.to_datetime(df['Event.Date'])

# %%
df['Publication.Date']=pd.to_datetime(df['Publication.Date'])
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\1823584368.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Publication.Date']=pd.to_datetime(df['Publication.Date'])

# %%
df['Publication.Date'].fillna(pd.Timestamp('1800-01-01'),inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\493709371.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Publication.Date'].fillna(pd.Timestamp('1800-01-01'),inplace=True)

# %%
object_columns = df.select_dtypes(include=['object']).columns
df[object_columns] = df[object_columns].fillna('NoData')

# 2. Replace 'N/A' values in object columns with "NoData"
df[object_columns] = df[object_columns].replace('N/A', 'NoData')

# %% [markdown]
# # 3. Data Preprocessing:

# %%
def get_IQR(df,colmn):
    for col in colmn:
        q1=df[col].quantile(0.25)
        q3=df[col].quantile(0.75)
        IQR=q3-q1
        lower_bound=q1-1.5*IQR
        upper_bound=q3+1.5*IQR
        print(f'Outlier of {col} , Q1={q1} , Q3={q3} , IQR={IQR} , Lower_bound={lower_bound} , Upper_bound={upper_bound}')

# %%
columns=['Number.of.Engines','Total.Uninjured' , 'Total.Minor.Injuries' ,'Total.Serious.Injuries' , 'Total.Fatal.Injuries']

# %%
new_df=df[(df['Total.Uninjured']!=0) | (df['Total.Minor.Injuries']!=0) | (df['Total.Serious.Injuries']!=0) | (df['Total.Fatal.Injuries']!=0)| ['fatality_level'] != 0]
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\850625365.py:1: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   new_df=df[(df['Total.Uninjured']!=0) | (df['Total.Minor.Injuries']!=0) | (df['Total.Serious.Injuries']!=0) | (df['Total.Fatal.Injuries']!=0)| ['fatality_level'] != 0]

# %%
get_IQR(new_df,columns)
# Out:
# Outlier of Number.of.Engines , Q1=1.0 , Q3=1.0 , IQR=0.0 , Lower_bound=1.0 , Upper_bound=1.0
# Outlier of Total.Uninjured , Q1=0.0 , Q3=2.0 , IQR=2.0 , Lower_bound=-3.0 , Upper_bound=5.0
# Outlier of Total.Minor.Injuries , Q1=0.0 , Q3=0.0 , IQR=0.0 , Lower_bound=0.0 , Upper_bound=0.0
# Outlier of Total.Serious.Injuries , Q1=0.0 , Q3=0.0 , IQR=0.0 , Lower_bound=0.0 , Upper_bound=0.0
# Outlier of Total.Fatal.Injuries , Q1=0.0 , Q3=0.0 , IQR=0.0 , Lower_bound=0.0 , Upper_bound=0.0

# %%
sns.boxplot(new_df['Total.Uninjured'])
plt.show()

# %%
sns.boxplot(new_df['Total.Minor.Injuries'])
plt.show()

# %%
sns.boxplot(new_df['Total.Serious.Injuries'])
plt.show()

# %%
sns.boxplot(new_df['Total.Fatal.Injuries'])
plt.show()

# %%
sns.boxplot(new_df['Number.of.Engines'])
plt.show()

# %%
new_df['event_year']=new_df['Event.Date'].dt.year

# %% [markdown]
# # 4. Exploratory Data Analysis (EDA) and Visualization:

# %% [markdown]
# Q1. Weather Conditions: What weather conditions (e.g., fog, rain, snow) are most commonly associated with accidents or incidents?Visualize the distribution of weather conditions during accidents using bar plots.

# %%
new_df['Weather.Condition'].replace('NoData','UNK',inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\247009398.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_df['Weather.Condition'].replace('NoData','UNK',inplace=True)

# %%
new_df['Weather.Condition'].replace('Unk','UNK',inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\1640256138.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_df['Weather.Condition'].replace('Unk','UNK',inplace=True)

# %%
weather_data=new_df.groupby('Weather.Condition')['Investigation.Type'].count().sort_values(ascending=False).plot(kind='bar')
weather_data.set_title('Distribution of weather conditions')
weather_data.set_xlabel('Weather Condition')
weather_data.set_ylabel('Count of Investigation Type')
plt.show()

# %% [markdown]
# Q2. Correlation between Weather and Severity: Is there a correlation between severe weather conditions and the severity of injuries or aircraft damage? Use scatter plots or heatmaps to show correlations.

# %%
new_df['sorted_weather']=new_df['Weather.Condition'].apply(lambda x: 1 if x == 'VMC' else (2 if x == 'IMC' else (3 if x == 'UNK' else None)))

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  datetime64[ns]
#  4   Location                88889 non-null  object
#  5   Country                 88889 non-null  object
#  6   Latitude                88889 non-null  object
#  7   Longitude               88889 non-null  object
#  8   Airport.Code            88889 non-null  object
#  9   Airport.Name            88889 non-null  object
#  10  Injury.Severity         88889 non-null  object
#  11  Aircraft.damage         88889 non-null  object
#  12  Aircraft.Category       88889 non-null  object
#  13  Registration.Number     88889 non-null  object
# ...

# %%
correlation=new_df['sorted_weather'].corr(new_df['fatality_level'])
print(f"Correlation between weather and fatality level: {correlation}")
# Out:
# Correlation between weather and fatality level: 0.06743511038829071

# %%
new_df['Aircraft.damage'].value_counts()
# Out:
# Aircraft.damage
# Substantial    64148
# Destroyed      18623
# NoData          3194
# Minor           2805
# Unknown          119
# Name: count, dtype: int64

# %%
new_df['Aircraft.damage']=new_df['Aircraft.damage'].replace('NoData','Unknown')

# %%
new_df['Aircraft.damage'].value_counts()
# Out:
# Aircraft.damage
# Substantial    64148
# Destroyed      18623
# Unknown         3313
# Minor           2805
# Name: count, dtype: int64

# %%
new_df['sorted_damage']=new_df['Aircraft.damage'].apply(lambda x : 1 if x == 'Substantial' else ( 2 if x == 'Destroyed' else (3 if x == 'Minor' else (4 if x=='Unknown' else None))))

# %%
new_df['sorted_damage'].value_counts()
# Out:
# sorted_damage
# 1    64148
# 2    18623
# 4     3313
# 3     2805
# Name: count, dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  datetime64[ns]
#  4   Location                88889 non-null  object
#  5   Country                 88889 non-null  object
#  6   Latitude                88889 non-null  object
#  7   Longitude               88889 non-null  object
#  8   Airport.Code            88889 non-null  object
#  9   Airport.Name            88889 non-null  object
#  10  Injury.Severity         88889 non-null  object
#  11  Aircraft.damage         88889 non-null  object
#  12  Aircraft.Category       88889 non-null  object
#  13  Registration.Number     88889 non-null  object
# ...

# %%
correlation_mat=new_df[['Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured','fatality_level','sorted_weather','sorted_damage']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_mat, annot=True, cmap='coolwarm', linewidths=0.5 , fmt=".2f")
plt.title('Correlation Heatmap: Weather, Injuries, and Fatality Level,and aircraft damage')
plt.show()

# %% [markdown]
# Q3. Airport Analysis: Are certain airports associated with a higher frequency of accidents? If so, what are the common factors (e.g., runway length, location)? Analyze and visualize the frequency of accidents by airport.

# %%
new_df['Investigation.Type'].value_counts()
# Out:
# Investigation.Type
# Accident    85015
# Incident     3874
# Name: count, dtype: int64

# %%
# Replace any row containing "private" or "pvt" (case-insensitive) with "private"
new_df['Airport.Name'] = new_df['Airport.Name'].str.replace(
    r'\b(private|pvt)\b',  # Matches "private" or "pvt" as whole words
    'Private',             # Replace with "private"
    case=False,            # Case insensitive
    regex=True             # Use regex for pattern matching
)

# If the column still contains other words, filter rows with "private/pvt" and replace the entire value
new_df.loc[new_df['Airport.Name'].str.contains(r'\b(private|pvt)\b', case=False, regex=True), 'Airport.Name'] = 'Private'

# Verify the changes
print(new_df['Airport.Name'])
# Out:
# 0        NoData
# 1        NoData
# 2        NoData
# 3        NoData
# 4        NoData
#           ...
# 88884    NoData
# 88885    NoData
# 88886    PAYSON
# 88887    NoData
# 88888    NoData
# Name: Airport.Name, Length: 88889, dtype: object
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\1562455032.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   new_df.loc[new_df['Airport.Name'].str.contains(r'\b(private|pvt)\b', case=False, regex=True), 'Airport.Name'] = 'Private'

# %%
new_df['Airport.Name'] = new_df['Airport.Name'].replace(
    ['NoData', 'NONE'],  # Values to categorize
    'UNKNOWN'            # The unified category
)

# %%
airport_counts = new_df['Airport.Name'].value_counts().reset_index()
airport_counts.columns = ['Airport Name', 'Count']

# Display all rows
pd.set_option('display.max_rows', None)
airport_counts.head()
# Out:
#     Airport Name  Count
# 0        UNKNOWN  36400
# 1        Private   1358
# 2  MERRILL FIELD     83
# 3       VAN NUYS     81
# 4      MUNICIPAL     78

# %%
q3=new_df[(new_df['Investigation.Type']=='Accident') & ~(new_df['Airport.Name']=='UNKNOWN')]
q3.head()
# Out:
#           Event.Id Investigation.Type Accident.Number Event.Date  \
# 7   20020909X01562           Accident      SEA82DA022 1982-01-01
# 8   20020909X01561           Accident      NYC82DA015 1982-01-01
# 9   20020909X01560           Accident      MIA82DA029 1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10 1982-01-01
# 13  20020917X02134           Accident      FTW82FRA14 1982-01-02
#
#             Location        Country Latitude Longitude Airport.Code  \
# 7        PULLMAN, WA  United States   NoData    NoData       NoData
# 8   EAST HANOVER, NJ  United States   NoData    NoData          N58
# 9   JACKSONVILLE, FL  United States   NoData    NoData          JAX
# 11      TUSKEGEE, AL  United States   NoData    NoData       NoData
# 13        HEARNE, TX  United States   NoData    NoData          T72
#
#           Airport.Name  ... Total.Minor.Injuries Total.Uninjured  \
# 7   BLACKBURN AG STRIP  ...                  0.0             2.0
# ...

# %%
q3g=q3.groupby('Airport.Name')['Investigation.Type'].count().sort_values(ascending=False).head(10).plot(kind='bar')
q3g.set_ylabel('count of accidents')
q3g.set_title('accidents by airport')
plt.show()

# %% [markdown]
# Q4. Aircraft Models: Which aircraft models have the highest rate of accidents or incidents? Create bar plots or pie charts to visualize accident rates by aircraft model

# %%
q4=new_df['Model'].value_counts().head(10).plot(kind='bar')
q4.set_ylabel('Count of Accidents/Incidents')
q4.set_title('Accidents/Incidents By Model')
plt.show()

# %% [markdown]
# Q5. Engine Type Analysis: Is there a particular engine type that is more frequently involved in accidents? Analyze and visualize accident frequency by engine type.

# %%
q5=new_df[(new_df['Engine.Type']!='NoData') & (new_df['Investigation.Type']=='Accident')]
q5.head()
# Out:
#          Event.Id Investigation.Type Accident.Number Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080 1948-10-24
# 1  20001218X45447           Accident      LAX94LA336 1962-07-19
# 2  20061025X01555           Accident      NYC07LA005 1974-08-30
# 3  20001218X45448           Accident      LAX96LA321 1977-06-19
# 5  20170710X52551           Accident      NYC79AA106 1979-09-17
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States     NoData     NoData       NoData
# 1   BRIDGEPORT, CA  United States     NoData     NoData       NoData
# 2    Saltville, VA  United States  36.922223 -81.878056       NoData
# 3       EUREKA, CA  United States     NoData     NoData       NoData
# 5       BOSTON, MA  United States  42.445277 -70.758333       NoData
#
#   Airport.Name  ... Total.Minor.Injuries Total.Uninjured Weather.Condition  \
# 0      UNKNOWN  ...                  0.0             0.0               UNK
# ...

# %%
q5g=q5['Engine.Type'].value_counts().head(5).plot(kind='bar')
q5g.set_ylabel("Count of Accidents")
q5g.set_title("Accidents by Engine Type")
plt.show()

# %% [markdown]
# Q6. Phase of Flight: During which phase of flight (e.g., takeoff, cruise, landing) do most accidents occur, and what are the common causes during these phases? Create visualizations such as bar plots to show accidents by flight phase

# %%
new_df['Broad.phase.of.flight'].value_counts()
# Out:
# Broad.phase.of.flight
# NoData         27165
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Unknown          548
# Other            119
# Name: count, dtype: int64

# %%
new_df['Broad.phase.of.flight'] = new_df['Broad.phase.of.flight'].replace(
    'NoData',  # Values to categorize
    'Unknown'            # The unified category
)

# %%
new_df['Broad.phase.of.flight'].value_counts()
# Out:
# Broad.phase.of.flight
# Unknown        27713
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Other            119
# Name: count, dtype: int64

# %%
q6=new_df[~(new_df['Broad.phase.of.flight']=='Unknown') & ~(new_df['Investigation.Type']=='Unknown')]
q6.head()
# Out:
#          Event.Id Investigation.Type Accident.Number Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080 1948-10-24
# 2  20061025X01555           Accident      NYC07LA005 1974-08-30
# 3  20001218X45448           Accident      LAX96LA321 1977-06-19
# 4  20041105X01764           Accident      CHI79FA064 1979-08-02
# 5  20170710X52551           Accident      NYC79AA106 1979-09-17
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States     NoData     NoData       NoData
# 2    Saltville, VA  United States  36.922223 -81.878056       NoData
# 3       EUREKA, CA  United States     NoData     NoData       NoData
# 4       Canton, OH  United States     NoData     NoData       NoData
# 5       BOSTON, MA  United States  42.445277 -70.758333       NoData
#
#   Airport.Name  ... Total.Minor.Injuries Total.Uninjured Weather.Condition  \
# 0      UNKNOWN  ...                  0.0             0.0               UNK
# ...

# %%
q6g=q6['Broad.phase.of.flight'].value_counts().plot(kind='bar')
q6g.set_ylabel('count of Accidents')
q6g.set_title('accidents by phase of flight')
plt.show()

# %%
b=q6.groupby(['Broad.phase.of.flight','Weather.Condition'])['Investigation.Type'].count().sort_values(ascending=False)

# %% [markdown]
# Q7. Impact of Flight Phase on Severity: How does the broad phase of flight impact injury severity or aircraft damage? Use boxplots or violin plots to show injury severity across flight phases.

# %%
columns_to_plot = ['Total.Serious.Injuries', 'Total.Minor.Injuries', 
                   'Total.Uninjured', 'fatality_level', 'sorted_damage']

# Set plot size and layout
fig, axes = plt.subplots(nrows=len(columns_to_plot), figsize=(12, 5 * len(columns_to_plot)))

# Loop through each column to create a boxplot
for i, column in enumerate(columns_to_plot):
    sns.violinplot(
        data=new_df,
        x='Broad.phase.of.flight',
        y=column,
        ax=axes[i],
        palette='Set3'
    )
    axes[i].set_title(f'{column} Across Broad Phases of Flight')
    axes[i].set_xlabel('Broad Phase of Flight')
    axes[i].set_ylabel(column)
    axes[i].tick_params(axis='x', rotation=45)

# Adjust spacing
plt.tight_layout()
plt.show()
plt.show()
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\3523368061.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\3523368061.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\3523368061.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# C:\Users\vivek\AppData\Local\Temp\ipykernel_13504\3523368061.py:9: FutureWarning:
#
# ...

# %% [markdown]
# Q8. Factors Associated with Fatality Rates: What factors (e.g., aircraft make, model, number of engines) are most associated with higher fatality rates? Analyze and visualize these factors using scatter plots or heatmaps.

# %%
# Select the required columns
correlation_data = new_df[['Number.of.Engines', 'fatality_level']]

# Calculate the correlation matrix
correlation_matrix = correlation_data.corr()

# Plot the correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap: Number of Engines vs Fatality Level')
plt.show()
plt.show()

# %%
sns.boxplot(new_df['fatality_level'])
plt.show()

# %% [markdown]
# Q9. Engine Count and Survival Likelihood: Does the number of engines on an aircraft influence the likelihood of survival or the severity of an accident? Use scatter plots or boxplots to visualize survival rates by engine count.

# %%
correlation_matrix = new_df[['Number.of.Engines', 'fatality_level', 
                                      'Total.Serious.Injuries', 
                                      'Total.Minor.Injuries', 
                                      'Total.Uninjured']].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap: Weather, Injuries, and Fatality Level,and aircraft damage')
plt.show()

# %% [markdown]
# Q10. Injury Analysis Across Locations: How does the total number of injuries (fatal, serious, minor) vary across different countries or locations? Create visualizations such as maps or bar plots to show injury distribution by location.

# %%
top_n=10
injury_levels = ['fatality_level', 'Total.Serious.Injuries', 'Total.Minor.Injuries']

# Create subplots (3 rows and 1 column)
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 18))

# Loop over injury levels and plot each one in a separate subplot
for i, injury in enumerate(injury_levels):
    # Sort the data by the current injury level in descending order and select the top N
    top_data = new_df.sort_values(by=injury, ascending=False).head(top_n)
    
    # Plot the data
    sns.barplot(x='Country', y=injury, data=top_data, ax=axes[i])
    axes[i].set_title(f'Top {top_n} Countries by {injury.replace("_", " ").title()}')
    axes[i].set_xlabel('Country')
    axes[i].set_ylabel(f'{injury.replace("_", " ").title()}')
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for readability

# Adjust layout to avoid overlapping subplots
plt.tight_layout()
plt.show()
